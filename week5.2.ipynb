# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.

# %% [markdown]
# 1.To improve readability of your code.
# 2.To enhance reusability of features.
# 3.To provide custom messages/instructions to users for specific use cases.
# 4.To add functionality to the custom exception classes like adding attributes and properties, adding methods, overriding the str and repr methods, and doing anything else that you can do with regular classes.

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
def print_exception_hierarchy(exception_class, indent=0):
    print(' ' * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)

print_exception_hierarchy(BaseException)
# Out:
# BaseException
#     Exception
#         TypeError
#             FloatOperation
#             MultipartConversionError
#         StopAsyncIteration
#         StopIteration
#         ImportError
#             ModuleNotFoundError
#             ZipImportError
#         OSError
#             ConnectionError
#                 BrokenPipeError
#                 ConnectionAbortedError
#                 ConnectionRefusedError
#                 ConnectionResetError
#                     RemoteDisconnected
#             BlockingIOError
#             ChildProcessError
#             FileExistsError
#             FileNotFoundError
#             IsADirectoryError
#             NotADirectoryError
#             InterruptedError
#                 InterruptedSystemCall
#             PermissionError
#             ProcessLookupError
#             TimeoutError
#             UnsupportedOperation
#             itimer_error
#             herror
#             gaierror
#             SSLError
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# The ArithmeticError class is the base class for all errors associated with arithmetic operations. The sub-classes that will be raised, depending on the arithmetic operation in fault, include:
#
# 1. ZeroDivisionError – It is raised when the second argument passed to the / or % standard division or modulo operator is zero.
# 2. OverflowError – It is raised when a mathematical operation exceeds the maximum limit of the data type.

# %%
#for example
try:
    a = 10/0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
#for example
try:
    import math
    print(math.exp(1000))
except OverflowError as e:
          print(e)
# Out:
# math range error

# %%
#for example
try:
    a = 2.5 + 2.5 + 3.5 - 3.5 -3.5 - 2.5 + 65.6
    
except FloatingPointError as e:
    print(e)

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# The LookupError exception in Python forms the base class for all exceptions that are raised when an index or a key is not found for a sequence or dictionary respectively. You can use LookupError exception class to handle both IndexError and KeyError exception classes

# %%
#for example
try:
    d = {"name" : "mdshahnawaz", "age" : 25}
    d["key"]
except KeyError as e:
    print(e)
# Out:
# 'key'

# %%
#for example
num = [12,13,3,4,5,6]
try:
    print(num[7])
except ImportError as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 4
#       2 num = [12,13,3,4,5,6]
#       3 try:
# ----> 4     print(num[7])
#       5 except ImportError as e:
#       6     print(e)
#
# IndexError: list index out of range

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# The module name is misspelled or does not exist.
# The module is not installed in your Python environment.
# The module file is not located in a directory that is included in the Python module search path.

# %% [markdown]
# The “ModuleNotFoundError” is raised when Python cannot locate an error. The most common cause of this error is forgetting to install a module or importing a module incorrectly.

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %% [markdown]
# 1: Be specific with exception handling:
# 2: Use multiple except blocks:
# 3: Handle exceptions gracefully:
# 4: Use finally block for cleanup:
# 5: Log exceptions:
# 6: Use context managers (with statement):
